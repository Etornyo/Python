# %%
import numpy as np
import pandas as pd
import datetime
import gc
import matplotlib.pyplot as plt
import seaborn as sns
import lightgbm as lgb
from sklearn.model_selection import StratifiedKFold
from sklearn.metrics import mean_squared_error

import xgboost as xgb
from datetime import datetime
from sklearn.model_selection import RandomizedSearchCV, GridSearchCV
from sklearn.metrics import roc_auc_score
from sklearn.model_selection import StratifiedKFold

import lightgbm
from lightgbm import LGBMClassifier

import warnings
warnings.filterwarnings('ignore')
np.random.seed(4590)

print('Finished imports...')
# Out:
# Finished imports...

# %%
train_client=pd.read_csv('client_train.csv')
test_client=pd.read_csv('client_test.csv')
train_invoice=pd.read_csv('invoice_train.csv')
test_invoice=pd.read_csv('invoice_test.csv')
print('Finished data read...')
# Out:
# Finished data read...

# %%
train_client.head(10)
# Out:
#    disrict            client_id  client_catg  region creation_date  target
# 0       60       train_Client_0           11     101    31/12/1994     0.0
# 1       69       train_Client_1           11     107    29/05/2002     0.0
# 2       62      train_Client_10           11     301    13/03/1986     0.0
# 3       69     train_Client_100           11     105    11/07/1996     0.0
# 4       62    train_Client_1000           11     303    14/10/2014     0.0
# 5       69   train_Client_10000           11     103    29/09/1993     0.0
# 6       62  train_Client_100000           11     309    07/06/2012     0.0
# 7       60  train_Client_100001           11     101    12/04/2006     0.0
# 8       62  train_Client_100002           11     301    31/12/2006     0.0
# 9       60  train_Client_100003           11     101    25/10/2011     0.0

# %%
train_invoice.head(10)
# Out:
#         client_id invoice_date  tarif_type  counter_number counter_statue  \
# 0  train_Client_0   2014-03-24          11         1335667              0
# 1  train_Client_0   2013-03-29          11         1335667              0
# 2  train_Client_0   2015-03-23          11         1335667              0
# 3  train_Client_0   2015-07-13          11         1335667              0
# 4  train_Client_0   2016-11-17          11         1335667              0
# 5  train_Client_0   2017-07-17          11         1335667              0
# 6  train_Client_0   2018-12-07          11         1335667              0
# 7  train_Client_0   2019-03-19          11         1335667              0
# 8  train_Client_0   2011-07-22          11         1335667              0
# 9  train_Client_0   2011-11-22          11         1335667              0
#
#    counter_code  reading_remarque  counter_coefficient  consommation_level_1  \
# 0           203                 8                    1                    82
# 1           203                 6                    1                  1200
# 2           203                 8                    1                   123
# 3           207                 8                    1                   102
# 4           207                 9                    1                   572
# 5           207                 9                    1                   314
# 6           207                 9                    1                   541
# 7           207                 9                    1                   585
# 8           203                 9                    1                  1200
# 9           203                 6                    1                  1082
#
#    consommation_level_2  consommation_level_3  consommation_level_4  \
# 0                     0                     0                     0
# 1                   184                     0                     0
# 2                     0                     0                     0
# 3                     0                     0                     0
# 4                     0                     0                     0
# 5                     0                     0                     0
# 6                     0                     0                     0
# 7                     0                     0                     0
# 8                   186                     0                     0
# 9                     0                     0                     0
#
#    old_index  new_index  months_number counter_type
# 0      14302      14384              4         ELEC
# 1      12294      13678              4         ELEC
# 2      14624      14747              4         ELEC
# 3      14747      14849              4         ELEC
# 4      15066      15638             12         ELEC
# 5      15638      15952              8         ELEC
# 6      15952      16493             12         ELEC
# 7      16493      17078              8         ELEC
# 8       7770       9156              4         ELEC
# 9       9156      10238              4         ELEC

# %%
d={"ELEC":0,"GAZ":1}
train_invoice['counter_type']=train_invoice['counter_type'].map(d)

# %%
train_client['client_catg'] = train_client['client_catg'].astype('object')
train_client['disrict'] = train_client['disrict'].astype('object')

test_client['client_catg'] = test_client['client_catg'].astype('object')
test_client['disrict'] = test_client['disrict'].astype('object')

# %%
train_invoice['counter_type'].value_counts()
# Out:
# counter_type
# 0    3079406
# 1    1397343
# Name: count, dtype: int64

# %%
for df in [train_invoice,test_invoice]:
    df['invoice_date'] = pd.to_datetime(df['invoice_date'])
    df['year'] = df['invoice_date'].dt.year
    df['month'] = df['invoice_date'].dt.month

# %%
aggs = {}
aggs['consommation_level_1'] = ['sum','max','min','mean','std']
aggs['consommation_level_2'] = ['sum','max','min','mean','std']
aggs['consommation_level_3'] = ['sum','max','min','mean','std']
aggs['consommation_level_4'] = ['sum','max','min','mean','std']

aggs['month'] = ['mean', 'max', 'min', 'std']
aggs['year'] = ['nunique','max','min','mean']

aggs['months_number'] = ['max','min','mean','sum']
aggs['reading_remarque'] = ['max','min','mean','std','sum']
aggs['counter_coefficient'] = ['max', 'min','mean']
aggs['counter_number'] = ['nunique']
aggs['counter_type'] = ['nunique','mean','sum']
aggs['counter_statue'] = ['nunique']
aggs['tarif_type'] = ['nunique','max','min']
aggs['counter_code'] = ['nunique','max','mean','min']


aggs['old_index'] = ['nunique','mean','std']
aggs['old_index'] = ['nunique','mean','std']

# %%
    agg_trans = train_invoice.groupby(['client_id']).agg(aggs)
    agg_trans.columns = ['_'.join(col).strip() for col in agg_trans.columns.values]
    agg_trans.reset_index(inplace=True)

    df = (train_invoice.groupby('client_id')
          .size()
          .reset_index(name='{}transactions_count'.format('1')))

    agg_trans = pd.merge(df, agg_trans, on='client_id', how='left')

# %%
agg_trans.head()
# Out:
#            client_id  1transactions_count  consommation_level_1_sum  \
# 0     train_Client_0                   35                     12334
# 1     train_Client_1                   37                     20629
# 2    train_Client_10                   18                     14375
# 3   train_Client_100                   20                        24
# 4  train_Client_1000                   14                      9292
#
#    consommation_level_1_max  consommation_level_1_min  \
# 0                      1200                        38
# 1                      1207                       190
# 2                      2400                       188
# 3                        15                         0
# 4                       800                       124
#
#    consommation_level_1_mean  consommation_level_1_std  \
# 0                 352.400000                310.343472
# 1                 557.540541                197.935960
# 2                 798.611111                513.841374
# 3                   1.200000                  3.607011
# 4                 663.714286                224.831365
#
#    consommation_level_2_sum  consommation_level_2_max  \
# 0                       370                       186
# 1                         0                         0
# 2                       682                       682
# 3                         0                         0
# 4                      1468                       400
#
#    consommation_level_2_min  ...  tarif_type_nunique  tarif_type_max  \
# 0                         0  ...                   1              11
# 1                         0  ...                   1              11
# 2                         0  ...                   1              11
# 3                         0  ...                   1              11
# 4                         0  ...                   1              11
#
#    tarif_type_min  counter_code_nunique  counter_code_max  counter_code_mean  \
# 0              11                     2               207         203.685714
# 1              11                     1               203         203.000000
# 2              11                     2               207         203.222222
# 3              11                     1               413         413.000000
# 4              11                     1               207         207.000000
#
#    counter_code_min  old_index_nunique  old_index_mean  old_index_std
# 0               203                 35     9444.542857    4527.744415
# 1               203                 37    14330.756757    6124.126094
# 2               203                 18    32873.000000    5317.180865
# 3               413                  4       94.150000       4.120232
# 4               207                 14     6900.428571    4732.111217
#
# [5 rows x 57 columns]

# %%
train = pd.merge(train_client,agg_trans, on='client_id', how='left')

# %%
test_client.head()
# Out:
#   disrict         client_id client_catg  region creation_date
# 0      62     test_Client_0          11     307    28/05/2002
# 1      69     test_Client_1          11     103    06/08/2009
# 2      62    test_Client_10          11     310    07/04/2004
# 3      60   test_Client_100          11     101    08/10/1992
# 4      62  test_Client_1000          11     301    21/07/1977

# %%
test_invoice.head()
# Out:
#        client_id invoice_date  tarif_type  counter_number  counter_statue  \
# 0  test_Client_0   2018-03-16          11          651208               0
# 1  test_Client_0   2014-03-21          11          651208               0
# 2  test_Client_0   2014-07-17          11          651208               0
# 3  test_Client_0   2015-07-13          11          651208               0
# 4  test_Client_0   2016-07-19          11          651208               0
#
#    counter_code  reading_remarque  counter_coefficient  consommation_level_1  \
# 0           203                 8                    1                   755
# 1           203                 8                    1                  1067
# 2           203                 8                    1                     0
# 3           203                 9                    1                   410
# 4           203                 9                    1                   412
#
#    consommation_level_2  consommation_level_3  consommation_level_4  \
# 0                     0                     0                     0
# 1                     0                     0                     0
# 2                     0                     0                     0
# 3                     0                     0                     0
# 4                     0                     0                     0
#
#    old_index  new_index  months_number counter_type  year  month
# 0      19145      19900              8         ELEC  2018      3
# 1      13725      14792              8         ELEC  2014      3
# 2      14792      14792              4         ELEC  2014      7
# 3      16122      16532              4         ELEC  2015      7
# 4      17471      17883              4         ELEC  2016      7

# %%
d={"ELEC":0,"GAZ":1}
test_invoice['counter_type']=test_invoice['counter_type'].map(d)

# %%
    agg_trans = test_invoice.groupby(['client_id']).agg(aggs)
    agg_trans.columns = ['_'.join(col).strip() for col in agg_trans.columns.values]
    agg_trans.reset_index(inplace=True)

    df = (test_invoice.groupby('client_id')
          .size()
          .reset_index(name='{}transactions_count'.format('1')))

    agg_trans = pd.merge(df, agg_trans, on='client_id', how='left')

# %%
test = pd.merge(test_client,agg_trans, on='client_id', how='left')

# %%
train.head(10)
# Out:
#   disrict            client_id client_catg  region creation_date  target  \
# 0      60       train_Client_0          11     101    31/12/1994     0.0
# 1      69       train_Client_1          11     107    29/05/2002     0.0
# 2      62      train_Client_10          11     301    13/03/1986     0.0
# 3      69     train_Client_100          11     105    11/07/1996     0.0
# 4      62    train_Client_1000          11     303    14/10/2014     0.0
# 5      69   train_Client_10000          11     103    29/09/1993     0.0
# 6      62  train_Client_100000          11     309    07/06/2012     0.0
# 7      60  train_Client_100001          11     101    12/04/2006     0.0
# 8      62  train_Client_100002          11     301    31/12/2006     0.0
# 9      60  train_Client_100003          11     101    25/10/2011     0.0
#
#    1transactions_count  consommation_level_1_sum  consommation_level_1_max  \
# 0                   35                     12334                      1200
# 1                   37                     20629                      1207
# 2                   18                     14375                      2400
# 3                   20                        24                        15
# 4                   14                      9292                       800
# 5                   48                     16901                      1414
# 6                   40                     11201                      1200
# 7                   78                     25545                      1101
# 8                    2                       225                       218
# 9                    5                      4254                      1200
#
#    consommation_level_1_min  ...  tarif_type_nunique  tarif_type_max  \
# 0                        38  ...                   1              11
# 1                       190  ...                   1              11
# 2                       188  ...                   1              11
# 3                         0  ...                   1              11
# 4                       124  ...                   1              11
# 5                         0  ...                   2              40
# 6                         0  ...                   2              40
# 7                         0  ...                   2              40
# 8                         7  ...                   1              11
# 9                       254  ...                   1              11
#
#    tarif_type_min  counter_code_nunique  counter_code_max  counter_code_mean  \
# 0              11                     2               207         203.685714
# 1              11                     1               203         203.000000
# 2              11                     2               207         203.222222
# 3              11                     1               413         413.000000
# 4              11                     1               207         207.000000
# 5              11                     2               203         124.625000
# 6              11                     2               413         209.000000
# 7              11                     2               203         106.538462
# 8              11                     1               413         413.000000
# 9              11                     1               467         467.000000
#
#    counter_code_min  old_index_nunique  old_index_mean  old_index_std
# 0               203                 35     9444.542857    4527.744415
# 1               203                 37    14330.756757    6124.126094
# 2               203                 18    32873.000000    5317.180865
# 3               413                  4       94.150000       4.120232
# 4               207                 14     6900.428571    4732.111217
# 5                 5                 45    13789.625000   10536.192177
# 6                 5                 37    19788.750000   16818.314522
# 7                 5                 71     6583.141026    6652.875339
# 8               413                  2        3.500000       4.949747
# 9               467                  5     9342.200000   12838.345812
#
# [10 rows x 62 columns]

# %%
test.head(10)
# Out:
#   disrict          client_id client_catg  region creation_date  \
# 0      62      test_Client_0          11     307    28/05/2002
# 1      69      test_Client_1          11     103    06/08/2009
# 2      62     test_Client_10          11     310    07/04/2004
# 3      60    test_Client_100          11     101    08/10/1992
# 4      62   test_Client_1000          11     301    21/07/1977
# 5      62  test_Client_10000          11     304    18/02/2015
# 6      62  test_Client_10001          11     303    13/09/2005
# 7      69  test_Client_10002          11     104    10/02/2011
# 8      62  test_Client_10003          11     309    12/04/2013
# 9      69  test_Client_10004          11     107    12/07/1993
#
#    1transactions_count  consommation_level_1_sum  consommation_level_1_max  \
# 0                   37                     18061                      1090
# 1                   22                     24011                      3600
# 2                   74                     40999                      1200
# 3                   40                      9774                       721
# 4                   53                     30114                      2400
# 5                   12                      7121                       962
# 6                   77                       791                       281
# 7                   77                     58274                      3805
# 8                   19                     12374                       800
# 9                   62                     35290                      2400
#
#    consommation_level_1_min  consommation_level_1_mean  ...  \
# 0                         0                 488.135135  ...
# 1                        11                1091.409091  ...
# 2                         0                 554.040541  ...
# 3                         0                 244.350000  ...
# 4                         0                 568.188679  ...
# 5                       159                 593.416667  ...
# 6                         0                  10.272727  ...
# 7                         0                 756.805195  ...
# 8                       329                 651.263158  ...
# 9                         0                 569.193548  ...
#
#    tarif_type_nunique  tarif_type_max  tarif_type_min  counter_code_nunique  \
# 0                   1              11              11                     1
# 1                   1              11              11                     1
# 2                   2              40              11                     2
# 3                   2              40              11                     2
# 4                   2              40              11                     2
# 5                   1              11              11                     1
# 6                   2              40              11                     2
# 7                   3              45              11                     3
# 8                   1              11              11                     1
# 9                   2              40              11                     2
#
#    counter_code_max  counter_code_mean  counter_code_min  old_index_nunique  \
# 0               203         203.000000               203                 36
# 1               433         433.000000               433                 22
# 2               207         119.648649                 5                 74
# 3               203         104.000000                 5                 39
# 4               203         135.754717                 5                 52
# 5               420         420.000000               420                 12
# 6               203         105.285714                 5                 18
# 7               420         209.415584                 5                 76
# 8               207         207.000000               207                 19
# 9               413         261.645161                 5                 56
#
#    old_index_mean  old_index_std
# 0    11389.837838    5401.043096
# 1    29380.772727   17638.422718
# 2    11774.054054   10987.377541
# 3    13623.725000   13242.361986
# 4    13927.471698   14371.199312
# 5    22582.583333   12430.670131
# 6      130.129870     123.719691
# 7    30106.129870   16807.909793
# 8     5941.315789    4553.366301
# 9    22820.500000   18398.577260
#
# [10 rows x 61 columns]

# %%
train.shape,test.shape
# Out:
# ((135493, 62), (58069, 61))

# %%
for df in [train,test]:
    df['creation_date'] = pd.to_datetime(df['creation_date'])
    df['year'] = df['creation_date'].dt.year
    df['month'] = df['creation_date'].dt.month
    df['month_diff'] = ((datetime.today() - df['creation_date']).dt.days)//30

# %%
col_to_drop = ['client_id', 'creation_date','old_index_std','reading_remarque_std','month_std','consommation_level_1_std', 'consommation_level_2_std', 'consommation_level_3_std','consommation_level_4_std']
for col in col_to_drop:
    if col in train.columns:
        train.drop([col], axis=1, inplace=True)
    if col in test.columns:
        test.drop([col], axis=1, inplace=True)

# %%
from sklearn import preprocessing
for f in test.columns:
    if train[f].dtype=='object' or test[f].dtype=='object': 
        lbl = preprocessing.LabelEncoder()
        lbl.fit(list(train[f].values) + list(test[f].values))
        train[f] = lbl.transform(list(train[f].values))
        test[f] = lbl.transform(list(test[f].values))

# %%
all_data_na = train.isnull().sum() 
all_data_na = all_data_na.drop(all_data_na[all_data_na == 0].index).sort_values(ascending=False)[:30]
missing_data = pd.DataFrame({'Missing ' :all_data_na})
missing_data.head(10)
# Out:
# Empty DataFrame
# Columns: [Missing ]
# Index: []

# %%
target=train['target']
train.drop('target',axis=1,inplace=True)

# %%
from sklearn.model_selection import KFold
from CatBoost import CatBoostClassifier
from sklearn.metrics import roc_auc_score


# invoiceYears = train_invoice['invoice_date'].dt.year.unique()


# Define KFold cross-validation
kf = KFold(n_splits=10, shuffle=True, random_state=42)

# Initialize lists to store predictions and errors
predictions = []
# errors = []
auc_scores = []

# Iterate over folds
for fold, (train_idx, valid_idx) in enumerate(kf.split(train)):
    # Extract training and validation data for this fold
    X_train_fold, X_valid_fold = train.iloc[train_idx], train.iloc[valid_idx]
    y_train_fold, y_valid_fold = target[train_idx], target[valid_idx]

    # Define and train your model
    model = CatBoostClassifier(
        iterations=900,
        depth=8,
        learning_rate=0.055,
        subsample=0.9,
        colsample_bylevel=0.9,
        random_seed=42,
        verbose=50  # Set to 'Verbose' for training logs
    )

    # Train the model
    model.fit(X_train_fold, y_train_fold)

    # Make predictions on the validation set
    fold_preds = model.predict(X_valid_fold)
    predictions.append(fold_preds)
    
    '''# Evaluate model and store predictions and errors
    rmse = np.sqrt(mean_squared_error(y_valid_fold, fold_preds))
    errors.append(rmse)
    predictions.append(fold_preds)'''
    
    
    # Calculate AUC score for the fold
    auc = roc_auc_score(y_valid_fold, fold_preds)
    auc_scores.append(auc)
    print(auc_scores)

    # Optionally, you can also make predictions on the test set for each fold and save them for ensembling later

# Calculate average error across folds
# mean_error = np.mean(errors)
# print("Mean RMSE:", mean_error)

# Optionally, you can also ensemble the predictions from different folds here

# After ensembling (if applicable), you can make predictions on the test set using the ensemble model
# And write the submission file
# Calculate average AUC score across folds


mean_auc = np.mean(auc_scores)
print("Mean AUC:", mean_auc)
# Out:
# 0:	learn: 0.6195903	total: 205ms	remaining: 3m 4s
# 50:	learn: 0.1615999	total: 5.73s	remaining: 1m 35s
# 100:	learn: 0.1508498	total: 9.94s	remaining: 1m 18s
# 150:	learn: 0.1453908	total: 15.2s	remaining: 1m 15s
# 200:	learn: 0.1410306	total: 21.7s	remaining: 1m 15s
# 250:	learn: 0.1372453	total: 27.3s	remaining: 1m 10s
# 300:	learn: 0.1332977	total: 32.1s	remaining: 1m 3s
# 350:	learn: 0.1297590	total: 36.4s	remaining: 57s
# 400:	learn: 0.1265849	total: 41.6s	remaining: 51.7s
# 450:	learn: 0.1236482	total: 46.1s	remaining: 45.9s
# 500:	learn: 0.1207674	total: 50.4s	remaining: 40.1s
# 550:	learn: 0.1180996	total: 54.4s	remaining: 34.5s
# 600:	learn: 0.1155319	total: 58.4s	remaining: 29.1s
# 650:	learn: 0.1131248	total: 1m 2s	remaining: 23.8s
# 700:	learn: 0.1105985	total: 1m 6s	remaining: 18.8s
# 750:	learn: 0.1082651	total: 1m 10s	remaining: 13.9s
# 800:	learn: 0.1059808	total: 1m 14s	remaining: 9.18s
# 850:	learn: 0.1037068	total: 1m 18s	remaining: 4.5s
# 899:	learn: 0.1013268	total: 1m 22s	remaining: 0us
# [0.5680391603565633]
# 0:	learn: 0.6161686	total: 74.8ms	remaining: 1m 7s
# 50:	learn: 0.1622959	total: 4.24s	remaining: 1m 10s
# 100:	learn: 0.1508336	total: 8.5s	remaining: 1m 7s
# 150:	learn: 0.1455879	total: 12.5s	remaining: 1m 1s
# 200:	learn: 0.1411021	total: 16.5s	remaining: 57.3s
# 250:	learn: 0.1370325	total: 20.5s	remaining: 52.9s
# 300:	learn: 0.1330796	total: 24.4s	remaining: 48.6s
# 350:	learn: 0.1298394	total: 28.4s	remaining: 44.4s
# 400:	learn: 0.1268219	total: 32.4s	remaining: 40.3s
# 450:	learn: 0.1239414	total: 36.4s	remaining: 36.2s
# 500:	learn: 0.1211652	total: 40.5s	remaining: 32.3s
# 550:	learn: 0.1185491	total: 44.6s	remaining: 28.3s
# 600:	learn: 0.1162068	total: 48.6s	remaining: 24.2s
# 650:	learn: 0.1138882	total: 52.7s	remaining: 20.1s
# 700:	learn: 0.1114037	total: 56.8s	remaining: 16.1s
# 750:	learn: 0.1093121	total: 1m	remaining: 12.1s
# 800:	learn: 0.1071299	total: 1m 4s	remaining: 8.03s
# 850:	learn: 0.1048198	total: 1m 9s	remaining: 3.98s
# 899:	learn: 0.1027174	total: 1m 13s	remaining: 0us
# [0.5680391603565633, 0.5722821371275664]
# 0:	learn: 0.6162656	total: 77.9ms	remaining: 1m 10s
# 50:	learn: 0.1621656	total: 4.45s	remaining: 1m 14s
# 100:	learn: 0.1507348	total: 8.6s	remaining: 1m 8s
# 150:	learn: 0.1453527	total: 12.6s	remaining: 1m 2s
# 200:	learn: 0.1410526	total: 16.8s	remaining: 58.3s
# 250:	learn: 0.1367606	total: 20.9s	remaining: 53.9s
# 300:	learn: 0.1329049	total: 25.1s	remaining: 49.9s
# 350:	learn: 0.1295959	total: 29.2s	remaining: 45.6s
# 400:	learn: 0.1262098	total: 33.3s	remaining: 41.4s
# 450:	learn: 0.1234849	total: 37.5s	remaining: 37.3s
# 500:	learn: 0.1209419	total: 41.5s	remaining: 33.1s
# 550:	learn: 0.1185472	total: 45.6s	remaining: 28.9s
# 600:	learn: 0.1161577	total: 49.7s	remaining: 24.7s
# 650:	learn: 0.1137082	total: 53.8s	remaining: 20.6s
# 700:	learn: 0.1115396	total: 57.9s	remaining: 16.4s
# 750:	learn: 0.1090330	total: 1m 2s	remaining: 12.3s
# 800:	learn: 0.1066176	total: 1m 6s	remaining: 8.17s
# 850:	learn: 0.1043778	total: 1m 10s	remaining: 4.04s
# 899:	learn: 0.1023959	total: 1m 14s	remaining: 0us
# [0.5680391603565633, 0.5722821371275664, 0.5644036458333334]
# 0:	learn: 0.6164794	total: 81.7ms	remaining: 1m 13s
# 50:	learn: 0.1629406	total: 4.31s	remaining: 1m 11s
# 100:	learn: 0.1518538	total: 8.52s	remaining: 1m 7s
# 150:	learn: 0.1466471	total: 12.6s	remaining: 1m 2s
# 200:	learn: 0.1423745	total: 16.8s	remaining: 58.4s
# 250:	learn: 0.1384479	total: 20.8s	remaining: 53.9s
# 300:	learn: 0.1345254	total: 25.2s	remaining: 50.1s
# 350:	learn: 0.1310874	total: 29.5s	remaining: 46.1s
# 400:	learn: 0.1277724	total: 33.6s	remaining: 41.9s
# 450:	learn: 0.1248576	total: 37.7s	remaining: 37.5s
# 500:	learn: 0.1221098	total: 41.8s	remaining: 33.3s
# 550:	learn: 0.1195097	total: 45.9s	remaining: 29s
# 600:	learn: 0.1170080	total: 50.3s	remaining: 25s
# 650:	learn: 0.1146898	total: 54.9s	remaining: 21s
# 700:	learn: 0.1122632	total: 59.1s	remaining: 16.8s
# 750:	learn: 0.1099331	total: 1m 3s	remaining: 12.6s
# 800:	learn: 0.1075926	total: 1m 7s	remaining: 8.36s
# 850:	learn: 0.1056420	total: 1m 11s	remaining: 4.13s
# 899:	learn: 0.1034590	total: 1m 15s	remaining: 0us
# [0.5680391603565633, 0.5722821371275664, 0.5644036458333334, 0.5802940462757764]
# 0:	learn: 0.6160889	total: 84ms	remaining: 1m 15s
# 50:	learn: 0.1621107	total: 4.38s	remaining: 1m 12s
# 100:	learn: 0.1508928	total: 8.63s	remaining: 1m 8s
# 150:	learn: 0.1455417	total: 13s	remaining: 1m 4s
# 200:	learn: 0.1411187	total: 17.2s	remaining: 59.8s
# 250:	learn: 0.1369196	total: 21.6s	remaining: 55.7s
# 300:	learn: 0.1331619	total: 25.7s	remaining: 51.1s
# 350:	learn: 0.1299786	total: 29.9s	remaining: 46.7s
# 400:	learn: 0.1271326	total: 34s	remaining: 42.3s
# 450:	learn: 0.1244100	total: 38.1s	remaining: 37.9s
# 500:	learn: 0.1216965	total: 42.5s	remaining: 33.9s
# 550:	learn: 0.1188989	total: 46.8s	remaining: 29.7s
# 600:	learn: 0.1161330	total: 51s	remaining: 25.4s
# 650:	learn: 0.1137150	total: 55.3s	remaining: 21.2s
# 700:	learn: 0.1114895	total: 59.6s	remaining: 16.9s
# 750:	learn: 0.1089387	total: 1m 3s	remaining: 12.7s
# 800:	learn: 0.1066028	total: 1m 8s	remaining: 8.41s
# 850:	learn: 0.1044493	total: 1m 12s	remaining: 4.16s
# 899:	learn: 0.1020579	total: 1m 16s	remaining: 0us
# [0.5680391603565633, 0.5722821371275664, 0.5644036458333334, 0.5802940462757764, 0.5817172502115533]
# 0:	learn: 0.6161813	total: 91.7ms	remaining: 1m 22s
# 50:	learn: 0.1616759	total: 4.32s	remaining: 1m 11s
# 100:	learn: 0.1505530	total: 8.58s	remaining: 1m 7s
# 150:	learn: 0.1450452	total: 12.7s	remaining: 1m 3s
# 200:	learn: 0.1406922	total: 16.9s	remaining: 58.8s
# 250:	learn: 0.1366934	total: 21s	remaining: 54.4s
# 300:	learn: 0.1327164	total: 25.2s	remaining: 50.2s
# 350:	learn: 0.1294868	total: 29.3s	remaining: 45.9s
# 400:	learn: 0.1262702	total: 33.6s	remaining: 41.8s
# 450:	learn: 0.1233029	total: 37.7s	remaining: 37.5s
# 500:	learn: 0.1204963	total: 41.9s	remaining: 33.4s
# 550:	learn: 0.1180323	total: 46s	remaining: 29.2s
# 600:	learn: 0.1151129	total: 50.5s	remaining: 25.1s
# 650:	learn: 0.1125249	total: 54.7s	remaining: 20.9s
# 700:	learn: 0.1103056	total: 59s	remaining: 16.7s
# 750:	learn: 0.1079816	total: 1m 3s	remaining: 12.6s
# 800:	learn: 0.1058540	total: 1m 7s	remaining: 8.35s
# 850:	learn: 0.1037221	total: 1m 23s	remaining: 4.82s
# 899:	learn: 0.1017179	total: 1m 27s	remaining: 0us
# [0.5680391603565633, 0.5722821371275664, 0.5644036458333334, 0.5802940462757764, 0.5817172502115533, 0.5775839554958218]
# 0:	learn: 0.6267648	total: 53ms	remaining: 47.7s
# 50:	learn: 0.1627562	total: 4.35s	remaining: 1m 12s
# 100:	learn: 0.1516610	total: 8.21s	remaining: 1m 4s
# 150:	learn: 0.1457036	total: 12.2s	remaining: 1m
# 200:	learn: 0.1411699	total: 16.2s	remaining: 56.3s
# 250:	learn: 0.1372473	total: 20.1s	remaining: 52s
# 300:	learn: 0.1334866	total: 24.1s	remaining: 47.9s
# 350:	learn: 0.1298725	total: 28.1s	remaining: 43.9s
# 400:	learn: 0.1265773	total: 32s	remaining: 39.8s
# 450:	learn: 0.1239310	total: 36s	remaining: 35.8s
# 500:	learn: 0.1212138	total: 39.9s	remaining: 31.8s
# 550:	learn: 0.1184063	total: 43.9s	remaining: 27.8s
# 600:	learn: 0.1159791	total: 47.8s	remaining: 23.8s
# 650:	learn: 0.1135801	total: 51.8s	remaining: 19.8s
# 700:	learn: 0.1112221	total: 55.7s	remaining: 15.8s
# 750:	learn: 0.1087931	total: 59.7s	remaining: 11.8s
# 800:	learn: 0.1067800	total: 1m 3s	remaining: 7.87s
# 850:	learn: 0.1046498	total: 1m 7s	remaining: 3.9s
# 899:	learn: 0.1025941	total: 1m 11s	remaining: 0us
# [0.5680391603565633, 0.5722821371275664, 0.5644036458333334, 0.5802940462757764, 0.5817172502115533, 0.5775839554958218, 0.5599711435789254]
# 0:	learn: 0.6161560	total: 72.5ms	remaining: 1m 5s
# 50:	learn: 0.1624898	total: 4.25s	remaining: 1m 10s
# 100:	learn: 0.1513959	total: 8.63s	remaining: 1m 8s
# 150:	learn: 0.1459627	total: 12.7s	remaining: 1m 3s
# 200:	learn: 0.1417186	total: 16.7s	remaining: 58s
# 250:	learn: 0.1374336	total: 20.6s	remaining: 53.3s
# 300:	learn: 0.1337690	total: 24.5s	remaining: 48.8s
# 350:	learn: 0.1301316	total: 28.7s	remaining: 44.8s
# 400:	learn: 0.1270843	total: 32.6s	remaining: 40.6s
# 450:	learn: 0.1238108	total: 36.7s	remaining: 36.5s
# 500:	learn: 0.1212232	total: 40.7s	remaining: 32.4s
# 550:	learn: 0.1184796	total: 44.7s	remaining: 28.3s
# 600:	learn: 0.1159656	total: 48.7s	remaining: 24.2s
# 650:	learn: 0.1133735	total: 52.8s	remaining: 20.2s
# 700:	learn: 0.1109602	total: 56.7s	remaining: 16.1s
# 750:	learn: 0.1084741	total: 1m	remaining: 12.1s
# 800:	learn: 0.1065414	total: 1m 4s	remaining: 8.03s
# 850:	learn: 0.1044686	total: 1m 8s	remaining: 3.97s
# 899:	learn: 0.1024127	total: 1m 13s	remaining: 0us
# [0.5680391603565633, 0.5722821371275664, 0.5644036458333334, 0.5802940462757764, 0.5817172502115533, 0.5775839554958218, 0.5599711435789254, 0.5782472306104409]
# 0:	learn: 0.6161540	total: 80.6ms	remaining: 1m 12s
# 50:	learn: 0.1635164	total: 4.3s	remaining: 1m 11s
# 100:	learn: 0.1517124	total: 8.43s	remaining: 1m 6s
# 150:	learn: 0.1462786	total: 12.4s	remaining: 1m 1s
# 200:	learn: 0.1419457	total: 16.3s	remaining: 56.6s
# 250:	learn: 0.1377631	total: 20.1s	remaining: 52.1s
# 300:	learn: 0.1338975	total: 24.1s	remaining: 48.1s
# 350:	learn: 0.1305645	total: 28.1s	remaining: 44s
# 400:	learn: 0.1275632	total: 31.9s	remaining: 39.7s
# 450:	learn: 0.1247471	total: 35.7s	remaining: 35.6s
# 500:	learn: 0.1219924	total: 39.5s	remaining: 31.5s
# 550:	learn: 0.1193605	total: 43.4s	remaining: 27.5s
# 600:	learn: 0.1168120	total: 47.2s	remaining: 23.5s
# 650:	learn: 0.1147259	total: 50.9s	remaining: 19.5s
# 700:	learn: 0.1121274	total: 54.8s	remaining: 15.6s
# 750:	learn: 0.1098229	total: 58.9s	remaining: 11.7s
# 800:	learn: 0.1075296	total: 1m 2s	remaining: 7.76s
# 850:	learn: 0.1053196	total: 1m 6s	remaining: 3.84s
# 899:	learn: 0.1031507	total: 1m 10s	remaining: 0us
# [0.5680391603565633, 0.5722821371275664, 0.5644036458333334, 0.5802940462757764, 0.5817172502115533, 0.5775839554958218, 0.5599711435789254, 0.5782472306104409, 0.566964112006855]
# 0:	learn: 0.6163307	total: 69.7ms	remaining: 1m 2s
# 50:	learn: 0.1635683	total: 3.97s	remaining: 1m 6s
# 100:	learn: 0.1516174	total: 7.94s	remaining: 1m 2s
# 150:	learn: 0.1459346	total: 11.7s	remaining: 58.3s
# 200:	learn: 0.1416149	total: 15.5s	remaining: 54.1s
# 250:	learn: 0.1376228	total: 19.4s	remaining: 50.3s
# 300:	learn: 0.1335865	total: 23.3s	remaining: 46.3s
# 350:	learn: 0.1304905	total: 27s	remaining: 42.2s
# 400:	learn: 0.1273187	total: 31.3s	remaining: 38.9s
# 450:	learn: 0.1243144	total: 35s	remaining: 34.9s
# 500:	learn: 0.1213319	total: 38.9s	remaining: 31s
# 550:	learn: 0.1186873	total: 43s	remaining: 27.2s
# 600:	learn: 0.1160604	total: 48.5s	remaining: 24.1s
# 650:	learn: 0.1137953	total: 53.2s	remaining: 20.3s
# 700:	learn: 0.1114396	total: 58.8s	remaining: 16.7s
# 750:	learn: 0.1089960	total: 1m 3s	remaining: 12.6s
# 800:	learn: 0.1067622	total: 1m 8s	remaining: 8.4s
# 850:	learn: 0.1045469	total: 1m 12s	remaining: 4.16s
# 899:	learn: 0.1024816	total: 1m 16s	remaining: 0us
# [0.5680391603565633, 0.5722821371275664, 0.5644036458333334, 0.5802940462757764, 0.5817172502115533, 0.5775839554958218, 0.5599711435789254, 0.5782472306104409, 0.566964112006855, 0.5691823568821941]
# Mean AUC: 0.571868503837903

# %%
preds_catboost = (predictions)

# Write CatBoost predictions to CSV file for submission
preds_catboost = pd.DataFrame(fold_preds[:, 1], columns=['target'])
preds_catboost.to_csv(f'submission_catboost_fold_{fold}.csv', index=False)
    
Print('Done')
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[148], line 4
#       1 preds_catboost = (predictions)
#       3 # Write CatBoost predictions to CSV file for submission
# ----> 4 preds_catboost = pd.DataFrame(fold_preds[:, 1], columns=['target'])
#       5 preds_catboost.to_csv(f'submission_catboost_fold_{fold}.csv', index=False)
#       7 Print('Done')
#
# IndexError: too many indices for array: array is 1-dimensional, but 2 were indexed

# %%
from catboost import CatBoostClassifier

# Create CatBoostClassifier instance
model= CatBoostClassifier(
    iterations=900,
    depth=8,
    learning_rate=0.05,
    subsample=0.9,
    colsample_bylevel=0.9,
    random_seed=42,
    verbose=50  # Set to 'Verbose' for training logs
)

# Train the model
# %time model.fit(train, target)

# After training, you can make predictions
predictions = model.predict_proba(test)

# Calculate the AUC score
auc = roc_auc_score(y_test, y_pred_proba)
print("AUC Score:", auc)
# Out:
# 0:	learn: 0.6228451	total: 100ms	remaining: 50s
# 50:	learn: 0.1652085	total: 5.01s	remaining: 44.1s
# 100:	learn: 0.1531686	total: 10.1s	remaining: 39.7s
# 150:	learn: 0.1477308	total: 15.5s	remaining: 35.7s
# 200:	learn: 0.1437199	total: 20.5s	remaining: 30.6s
# 250:	learn: 0.1401112	total: 25.6s	remaining: 25.4s
# 300:	learn: 0.1366255	total: 30.4s	remaining: 20.1s
# 350:	learn: 0.1335095	total: 35.7s	remaining: 15.1s
# 400:	learn: 0.1307856	total: 41s	remaining: 10.1s
# 450:	learn: 0.1280829	total: 46.2s	remaining: 5.02s
# 499:	learn: 0.1256822	total: 50.7s	remaining: 0us
# CPU times: total: 4min 8s
# Wall time: 56 s

# %%
submission = pd.DataFrame({
        "client_id": sub["client_id"],
        "target": preds[1]
    })
submission.to_csv('submission_fraud_cat.csv', index=False)

# %%
import xgboost as xgb

# Create XGBoost Classifier instance
model = xgb.XGBClassifier(
    n_estimators=500,
    max_depth=9,
    learning_rate=0.055,
    subsample=0.9,
    colsample_bytree=0.9,
    random_state=42,
    verbosity=1  # Set to 1 for training logs
)

# Train the model
# %time model.fit(train, target)

# After training, you can make predictions
predictions = model.predict(test)
# Out:
# CPU times: total: 4min 48s
# Wall time: 1min

# %%
pred=model.predict_proba(test)

# %%
preds = (pred)

# %%
preds = pd.DataFrame(preds)

# %%
preds.head(10)
# Out:
#           0         1
# 0  0.979904  0.020096
# 1  0.974732  0.025268
# 2  0.997406  0.002594
# 3  0.997638  0.002362
# 4  0.974954  0.025046
# 5  0.984502  0.015498
# 6  0.999922  0.000079
# 7  0.669456  0.330544
# 8  0.999212  0.000788
# 9  0.982634  0.017366

# %%
sub=pd.read_csv('SampleSubmission (4).csv')

# %%
submission = pd.DataFrame({
        "client_id": sub["client_id"],
        "target": preds[1]
    })
submission.to_csv('submission_fraud_new.csv', index=False)

# %%
submission.head(10)
# Out:
#            client_id    target
# 0      test_Client_0  0.020096
# 1      test_Client_1  0.025268
# 2     test_Client_10  0.002594
# 3    test_Client_100  0.002362
# 4   test_Client_1000  0.025046
# 5  test_Client_10000  0.015498
# 6  test_Client_10001  0.000079
# 7  test_Client_10002  0.330544
# 8  test_Client_10003  0.000788
# 9  test_Client_10004  0.017366
